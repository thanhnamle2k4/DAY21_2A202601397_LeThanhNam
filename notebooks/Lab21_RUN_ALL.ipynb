# %% [markdown]
# # Lab 21 — Fine-tuning LLMs · RUN ALL (T4)
#
# Chay tu tren xuong. Runtime > Change runtime type > **T4 GPU** truoc khi bat dau.
#
# | O | Lam gi | Thoi gian |
# |---|---|---|
# | 1 | clone + install | ~1 phut |
# | 2 | smoke: import + unit test | ~30 giay |
# | 3 | **core pipeline NB1 -> NB5** | ~80 phut |
# | 4 | gatekeeper + in ket qua | ~10 giay |

# %%
# @title 1. Setup — clone + install (chạy ô này trước)
import os, subprocess, sys

REPO = "https://github.com/hieutrungdao/Day21-Track3-Finetuning-Lab.git"
if not os.path.exists("Day21-Track3-Finetuning-Lab"):
    subprocess.run(["git", "clone", "-q", REPO], check=True)
os.chdir("/content/Day21-Track3-Finetuning-Lab")
subprocess.run(["git", "pull", "-q"], check=False)
sys.path.insert(0, "src")

# Install from requirements.txt, NOT a copied list. The copied list is how the
# torchao>=0.16 pin reached requirements.txt and this bootstrap on different days --
# and a bootstrap missing a pin does not fail here, it fails 10 minutes later inside
# get_peft_model(). One source of truth. torch is preinstalled on Colab and
# requirements.txt pins it compatibly, so that line is a no-op.
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
               check=True)

import torch
print("commit :", subprocess.run(["git","rev-parse","--short","HEAD"],
                                 capture_output=True, text=True).stdout.strip())
print("GPU    :", torch.cuda.get_device_name(0) if torch.cuda.is_available()
      else "NONE — Runtime > Change runtime type > T4 GPU")
if torch.cuda.is_available():
    print("VRAM   : %.1f GB" % (torch.cuda.get_device_properties(0).total_memory/1024**3))
# Out:
# commit : 4f619a4
# GPU    : Tesla T4
# VRAM   : 14.6 GB

# %%
# @title 2. Smoke — imports, seed data, unit tests (no GPU needed)
# !python scripts/verify.py --smoke
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.24s
#
# 6 passed · 0 warnings · 1 failures
#
# Not ready to submit — fix the FAILs above.

# %%
# @title 3. Core pipeline — NB1 → NB5
# EVAL_LIMIT truncates both eval sets: "" = full run (submittable),
# 8 = ~fast smoke pass. STAGES lets you resume after a failure.
import os
COMPUTE_TIER = "T4"        # @param ["CPU","LAPTOP","T4","BIGGPU"]
EVAL_LIMIT   = ""         # @param ["", "4", "8", "16", "25"]
STAGES       = "nb2 nb5"   # @param {type:"string"}

os.environ["COMPUTE_TIER"] = COMPUTE_TIER
if EVAL_LIMIT:
    os.environ["EVAL_LIMIT"] = EVAL_LIMIT
else:
    os.environ.pop("EVAL_LIMIT", None)

from labkit import device
print(device.banner(), "\n")

# !python scripts/colab_run.py {STAGES}
# Out:
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
#
# tier=T4  mask=assistant-only  eval_limit=full
#
# ========================================================================
# NB2 — freeze eval + three baselines
# ========================================================================
# target=50  regression=15  tier=T4
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1075.46it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:35<00:00, 11.86it/s]
#   [(a) base + naive prompt/target] batch 1/13     15s elapsed  ~  176s left
#   [(a) base + naive prompt/target] batch 2/13     28s elapsed  ~  156s left
#   [(a) base + naive prompt/target] batch 3/13     42s elapsed  ~  139s left
#   [(a) base + naive prompt/target] batch 4/13     55s elapsed  ~  124s left
#   [(a) base + naive prompt/target] batch 5/13     69s elapsed  ~  110s left
#   [(a) base + naive prompt/target] batch 6/13     82s elapsed  ~   95s left
#   [(a) base + naive prompt/target] batch 7/13     94s elapsed  ~   81s left
#   [(a) base + naive prompt/target] batch 8/13    107s elapsed  ~   67s left
#   [(a) base + naive prompt/target] batch 9/13    120s elapsed  ~   53s left
#   [(a) base + naive prompt/target] batch 10/13    133s elapsed  ~   40s left
#   [(a) base + naive prompt/target] batch 11/13    147s elapsed  ~   27s left
#   [(a) base + naive prompt/target] batch 12/13    160s elapsed  ~   13s left
#   [(a) base + naive prompt/target] batch 13/13    173s elapsed  ~    0s left
#   [(a) base + naive prompt/target] done: 50 prompts in 173s
#   [(a) base + naive prompt/regression] batch 1/4      5s elapsed  ~   16s left
#   [(a) base + naive prompt/regression] batch 2/4     13s elapsed  ~   13s left
#   [(a) base + naive prompt/regression] batch 3/4     21s elapsed  ~    7s left
#   [(a) base + naive prompt/regression] batch 4/4     30s elapsed  ~    0s left
#   [(a) base + naive prompt/regression] done: 15 prompts in 30s
# (a) base + naive prompt      target=0.000  regression=0.758  format=0.000  3458ms
#   [(b) base + optimized prompt/target] batch 1/13      5s elapsed  ~   55s left
#   [(b) base + optimized prompt/target] batch 2/13      9s elapsed  ~   49s left
#   [(b) base + optimized prompt/target] batch 3/13     13s elapsed  ~   43s left
#   [(b) base + optimized prompt/target] batch 4/13     17s elapsed  ~   39s left
#   [(b) base + optimized prompt/target] batch 5/13     22s elapsed  ~   35s left
#   [(b) base + optimized prompt/target] batch 6/13     26s elapsed  ~   30s left
#   [(b) base + optimized prompt/target] batch 7/13     30s elapsed  ~   26s left
#   [(b) base + optimized prompt/target] batch 8/13     34s elapsed  ~   21s left
#   [(b) base + optimized prompt/target] batch 9/13     38s elapsed  ~   17s left
#   [(b) base + optimized prompt/target] batch 10/13     42s elapsed  ~   13s left
#   [(b) base + optimized prompt/target] batch 11/13     47s elapsed  ~    9s left
#   [(b) base + optimized prompt/target] batch 12/13     51s elapsed  ~    4s left
#   [(b) base + optimized prompt/target] batch 13/13     55s elapsed  ~    0s left
#   [(b) base + optimized prompt/target] done: 50 prompts in 55s
#   [(b) base + optimized prompt/regression] batch 1/4      6s elapsed  ~   17s left
#   [(b) base + optimized prompt/regression] batch 2/4     13s elapsed  ~   13s left
#   [(b) base + optimized prompt/regression] batch 3/4     21s elapsed  ~    7s left
#   [(b) base + optimized prompt/regression] batch 4/4     29s elapsed  ~    0s left
#   [(b) base + optimized prompt/regression] done: 15 prompts in 29s
# (b) base + optimized prompt  target=0.765  regression=0.758  format=1.000  1091ms
# {
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "baseline_a": {
#     "target": 0.0,
#     "regression": 0.7577777777777778,
#     "format": 0.0,
#     "latency_ms": 3457.9670853800244,
#     "n": 50,
#     "extra": {}
#   },
#   "baseline_b": {
#     "target": 0.765,
#     "regression": 0.7577777777777778,
#     "format": 1.0,
#     "latency_ms": 1090.9393792999617,
#     "n": 50,
#     "extra": {}
#   },
#   "optimized_prompt_sha": "719e74d3b6232053",
#   "n_target": 50,
#   "n_regression": 15,
#   "eval_limit": null,
#   "smoke_mode": false
# }
#
# -- NB2 ok in 337s
#
# ========================================================================
# NB5 — four-group eval + verdict
# ========================================================================
# baseline (b) target = 0.765 — đây là mốc phải vượt
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 969.11it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:35<00:00, 11.87it/s]
#   [ft/target] batch 1/13      7s elapsed  ~   82s left
#   [ft/target] batch 2/13     13s elapsed  ~   70s left
#   [ft/target] batch 3/13     18s elapsed  ~   60s left
#   [ft/target] batch 4/13     24s elapsed  ~   54s left
#   [ft/target] batch 5/13     29s elapsed  ~   47s left
#   [ft/target] batch 6/13     36s elapsed  ~   42s left
#   [ft/target] batch 7/13     40s elapsed  ~   35s left
#   [ft/target] batch 8/13     46s elapsed  ~   29s left
#   [ft/target] batch 9/13     51s elapsed  ~   23s left
#   [ft/target] batch 10/13     56s elapsed  ~   17s left
#   [ft/target] batch 11/13     62s elapsed  ~   11s left
#   [ft/target] batch 12/13     67s elapsed  ~    6s left
#   [ft/target] batch 13/13     74s elapsed  ~    0s left
#   [ft/target] done: 50 prompts in 74s
#   [ft/regression] batch 1/4     11s elapsed  ~   33s left
#   [ft/regression] batch 2/4     24s elapsed  ~   24s left
#   [ft/regression] batch 3/4     36s elapsed  ~   12s left
#   [ft/regression] batch 4/4     49s elapsed  ~    0s left
#   [ft/regression] done: 15 prompts in 49s
# fine-tune: {'target': 0.975, 'regression': 0.41111111111111115, 'format': 1.0, 'latency_ms': 1473.8405447000332, 'n': 50, 'extra': {'valid_trace_rate': 0.0}}
# | run | target | regression | format | latency_ms | n |
# |---|---|---|---|---|---|
# | (a) base + naive prompt | 0.0 | 0.7578 | 0.0 | 3458.0 | 50 |
# | (b) base + optimized prompt | 0.765 | 0.7578 | 1.0 | 1090.9 | 50 |
# | (c) LoRA fine-tune | 0.975 | 0.4111 | 1.0 | 1473.8 | 50 |
# FAILED
#  - general capability regressed by 0.347 (tolerance 0.020). See deck §14.3 — add 1-5% replay data.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1014.83it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:36<00:00, 11.81it/s]
#   [attn_only/target] batch 1/13      3s elapsed  ~   41s left
#   [attn_only/target] batch 2/13      7s elapsed  ~   39s left
#   [attn_only/target] batch 3/13     11s elapsed  ~   37s left
#   [attn_only/target] batch 4/13     15s elapsed  ~   33s left
#   [attn_only/target] batch 5/13     18s elapsed  ~   29s left
#   [attn_only/target] batch 6/13     22s elapsed  ~   26s left
#   [attn_only/target] batch 7/13     26s elapsed  ~   22s left
#   [attn_only/target] batch 8/13     29s elapsed  ~   18s left
#   [attn_only/target] batch 9/13     32s elapsed  ~   14s left
#   [attn_only/target] batch 10/13     36s elapsed  ~   11s left
#   [attn_only/target] batch 11/13     40s elapsed  ~    7s left
#   [attn_only/target] batch 12/13     43s elapsed  ~    4s left
#   [attn_only/target] batch 13/13     47s elapsed  ~    0s left
#   [attn_only/target] done: 50 prompts in 47s
# attn_only: target=0.970  format=1.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 835.94it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:36<00:00, 11.73it/s]
#   [wrong_lr/target] batch 1/13     21s elapsed  ~  251s left
#   [wrong_lr/target] batch 2/13     41s elapsed  ~  228s left
#   [wrong_lr/target] batch 3/13     62s elapsed  ~  208s left
#   [wrong_lr/target] batch 4/13     84s elapsed  ~  188s left
#   [wrong_lr/target] batch 5/13    104s elapsed  ~  167s left
#   [wrong_lr/target] batch 6/13    125s elapsed  ~  146s left
#   [wrong_lr/target] batch 7/13    145s elapsed  ~  125s left
#   [wrong_lr/target] batch 8/13    166s elapsed  ~  104s left
#   [wrong_lr/target] batch 9/13    187s elapsed  ~   83s left
#   [wrong_lr/target] batch 10/13    208s elapsed  ~   62s left
#   [wrong_lr/target] batch 11/13    228s elapsed  ~   41s left
#   [wrong_lr/target] batch 12/13    249s elapsed  ~   21s left
#   [wrong_lr/target] batch 13/13    269s elapsed  ~    0s left
#   [wrong_lr/target] done: 50 prompts in 269s
# wrong_lr: target=0.000  format=0.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 906.19it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:39<00:00, 10.87it/s]
#   [qlora/target] batch 1/13      7s elapsed  ~   83s left
#   [qlora/target] batch 2/13     15s elapsed  ~   80s left
#   [qlora/target] batch 3/13     21s elapsed  ~   71s left
#   [qlora/target] batch 4/13     29s elapsed  ~   65s left
#   [qlora/target] batch 5/13     36s elapsed  ~   58s left
#   [qlora/target] batch 6/13     43s elapsed  ~   50s left
#   [qlora/target] batch 7/13     50s elapsed  ~   43s left
#   [qlora/target] batch 8/13     57s elapsed  ~   36s left
#   [qlora/target] batch 9/13     65s elapsed  ~   29s left
#   [qlora/target] batch 10/13     71s elapsed  ~   21s left
#   [qlora/target] batch 11/13     79s elapsed  ~   14s left
#   [qlora/target] batch 12/13     86s elapsed  ~    7s left
#   [qlora/target] batch 13/13     93s elapsed  ~    0s left
#   [qlora/target] done: 50 prompts in 93s
# qlora: target=0.940  format=1.000
#
# | run | target | format | latency_ms | n |
# |---|---|---|---|---|
# | correct | 0.975 | 1.0 | 1473.8 | 50 |
# | attn_only | 0.97 | 1.0 | 949.0 | 50 |
# | wrong_lr | 0.0 | 0.0 | 5376.8 | 50 |
# | qlora | 0.94 | 1.0 | 1866.8 | 50 |
# --- 3 ca TỆ NHẤT (bắt buộc đưa vào report) ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 3 | Cho mình hỏi, mình đặt bình giữ nhiệt mã đơn VN804124. Chưa thấy tiền. | 0.75 | {"intent": "hoan_tien", "urgency": "trung_binh", "product": "bình giữ nhiệt", "sentiment": |
# | 12 | Shop ơi, mình đặt áo khoác gió mã đơn VN613097. Bị lỗi. Khi nào tiện.  | 0.75 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "áo khoác gió", "sentiment" |
# | 39 | Chào shop, mình đặt nồi chiên không dầu mã đơn VN949966. Hoàn tiền. Kh | 0.75 | {"intent": "hoan_tien", "urgency": "trung_binh", "product": "nồi chiên không dầu", "sentim |
#
# --- 3 ca TỐT NHẤT ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 47 | Cho mình hỏi, mình đặt ốp lưng điện thoại mã đơn DH936478. Shipper khô | 1.0 | {"intent": "van_chuyen", "urgency": "thap", "product": "ốp lưng điện thoại", "sentiment":  |
# | 48 | Alo shop, mình đặt ốp lưng điện thoại mã đơn DH734695. Giá bao nhiêu.  | 1.0 | {"intent": "hoi_thong_tin", "urgency": "trung_binh", "product": "ốp lưng điện thoại", "sen |
# | 49 | Chào shop, mình đặt ốp lưng điện thoại mã đơn VN833689. Sai màu. Sớm n | 1.0 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "ốp lưng điện thoại", "sent |
#
# -- NB5 ok in 711s
#
# ----------------------------------------
# stage timings
#   nb2       337s  (5.6 min)
#   nb5       711s  (11.9 min)
#   total    1048s (17.5 min)

# %%
# @title 4. Gatekeeper + results
# !python scripts/verify.py
print("\n================ results/ ================")
# !ls -la results/
# !echo && echo "---- runs.csv ----" && cat results/runs.csv 2>/dev/null
# !echo && echo "---- verdict.json ----" && cat results/verdict.json 2>/dev/null
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.71s
# [  ok  ] results/template_check.json
# [  ok  ] results/mask_proof.json
# [  ok  ] results/token_stats.json
# [  ok  ] results/baselines_frozen.json
# [  ok  ] results/runs.csv
# [  ok  ] results/verdict.json
# [  ok  ] results/autopsy.json
# [  ok  ] submission/REPORT.md
# [ FAIL ] REPORT.md filled in                              6 placeholders still present (<điền>, <paste>, ...) — this is still the template
# [  ok  ] mask proof asserts
# [ FAIL ] full eval set used                               EVAL_LIMIT=8 — this run scored 8 target items, not the full set. Smoke mode is for iterating; unset EVAL_LIMIT and re-run NB2+NB5 to submit.
# [  ok  ] baseline (b) prompt unmodified
# [  ok  ] baseline (b) beats (a)                           (a)=0.000 -> (b)=0.688
# [  ok  ] eval sets unmodified
# [  ok  ] NB3 run present
# [  ok  ] NB4 contrast runs
# [  ok  ] all runs share ONE step budget                   ['attn_only', 'correct', 'qlora', 'wrong_lr'] at 30 steps
# [  ok  ] attn_only is a FAIR contrast                     32,456,704 vs 32,464,896 trainable params
# [  ok  ] verdict recorded                                 FAILED (target Δ +0.281, regression Δ -0.250)
# [ warn ] note                                             A FAILED verdict is fully gradeable — analyse it honestly in REPORT.md rather than loosening the gate.
#
# 23 passed · 1 warnings · 3 failures
#
# Not ready to submit — fix the FAILs above.
#
# ================ results/ ================
# total 40
# drwxr-xr-x  2 root root 4096 Aug 21 04:57 .
# drwxr-xr-x 15 root root 4096 Aug 21 03:39 ..
# -rw-r--r--  1 root root  435 Aug 21 04:57 autopsy.json
# -rw-r--r--  1 root root  481 Aug 21 03:43 baselines_frozen.json
# -rw-r--r--  1 root root    0 Aug 21 03:26 .gitkeep
# -rw-r--r--  1 root root  592 Aug 21 03:40 mask_proof.json
# -rw-r--r--  1 root root 2205 Aug 21 04:57 qualitative.json
# -rw-r--r--  1 root root 1101 Aug 21 04:52 runs.csv
# -rw-r--r--  1 root root  277 Aug 21 03:40 template_check.json
# -rw-r--r--  1 root root  115 Aug 21 03:40 token_stats.json
# -rw-r--r--  1 root root  772 Aug 21 04:54 verdict.json
#
# ---- runs.csv ----
# run,label,tier,model,precision,placement,n_target_modules,r,lora_alpha,learning_rate,load_in_4bit,trainable_params,train_seconds,peak_vram_gb,final_loss,mask_mode,max_steps,teaches
# correct,all-linear · r=16 · LR 10x · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,False,32464896,1016.6,12.01,0.6249,assistant-only,30,
# attn_only,"q,v only · r=matched · LR 10x · 16-bit",T4,unsloth/Qwen3.5-4B,fp16,attn-only,2,283,566,0.0001,False,32456704,859.3,12.02,0.5377,,30,"Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win."
# wrong_lr,all-linear · r=16 · LR 1x (full-FT scale) · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,1e-05,False,32464896,998.4,12.01,1.5704,,30,Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# qlora,all-linear · r=16 · LR 10x · 4-bit QLoRA,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,True,32464896,1056.2,7.09,0.7058,,30,The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
#
# ---- verdict.json ----
# {
#   "comparison": [
#     {
#       "run": "(a) base + naive prompt",
#       "target": 0.0,
#       "regression": 0.75,
#       "format": 0.0,
#       "latency_ms": 3535.4,
#       "n": 8
#     },
#     {
#       "run": "(b) base + optimized prompt",
#       "target": 0.6875,
#       "regression": 0.75,
#       "format": 1.0,
#       "latency_ms": 1085.2,
#       "n": 8
#     },
#     {
#       "run": "(c) LoRA fine-tune",
#       "target": 0.9688,
#       "regression": 0.5,
#       "format": 1.0,
#       "latency_ms": 1670.1,
#       "n": 8
#     }
#   ],
#   "verdict": {
#     "passed": false,
#     "reasons": [
#       "general capability regressed by 0.250 (tolerance 0.020). See deck §14.3 — add 1-5% replay data."
#     ],
#     "target_delta": 0.28125,
#     "regression_delta": -0.25
#   },
#   "valid_trace_rate": 0.0
# }

# %%
# Nén thư mục results và adapter đã train
# !zip -r lab21_results.zip results/ adapters/correct/

from google.colab import files
files.download("lab21_results.zip")
# Out:
# updating: results/ (stored 0%)
# updating: results/runs.csv (deflated 47%)
# updating: results/token_stats.json (deflated 34%)
# updating: results/.gitkeep (stored 0%)
# updating: results/mask_proof.json (deflated 42%)
# updating: results/template_check.json (deflated 36%)
# updating: results/autopsy.json (deflated 67%)
# updating: results/qualitative.json (deflated 86%)
# updating: results/verdict.json (deflated 57%)
# updating: results/baselines_frozen.json (deflated 52%)
# updating: adapters/correct/ (stored 0%)
# updating: adapters/correct/chat_template.jinja (deflated 76%)
# updating: adapters/correct/adapter_config.json (deflated 62%)
# updating: adapters/correct/tokenizer_config.json (deflated 65%)
# updating: adapters/correct/tokenizer.json (deflated 80%)
# updating: adapters/correct/adapter_model.safetensors (deflated 8%)
# updating: adapters/correct/README.md (deflated 65%)
